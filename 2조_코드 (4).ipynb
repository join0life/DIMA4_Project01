# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

matplotlib.rcParams['font.family'] = 'Malgun Gothic'
matplotlib.rcParams['font.size'] = 12
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
data = pd.read_excel('최종1수요 변수찾기 리서치 (2).xlsx')

# %%
data.set_index('Unnamed: 0',inplace=True)

# %%
data['2달_이동평균'] = data['수출(금액)'].rolling(30).mean()

# %%
data[28:]
data.to_excel('수요이평선.xlsx')

# %%
data[28:]
# Out:
#             seaweed_us_google_search  キンパ_jp_instagram_search  \
# Unnamed: 0
# 2014-05-01                   49040.0                      0.0
# 2014-06-01                   91820.0                      0.0
# 2014-07-01                    5430.0                      0.0
# 2014-08-01                   91880.0                      0.0
# 2014-09-01                   90800.0                      0.0
# ...                              ...                      ...
# 2024-11-01                       NaN                      NaN
# 2024-12-01                       NaN                      NaN
# 2025-01-01                       NaN                      NaN
# 2025-02-01                       NaN                      NaN
# 2025-02-02                       NaN                      NaN
#
#             kimbap: (미국)_관심도_웹  kimbap: (미국)_관심도_유튜브  のり: (일본)_관심도_웹  \
# Unnamed: 0
# 2014-05-01                 1.0                   0.0            38.0
# ...

# %%
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args: 'float | ArrayLike | str', scalex: 'bool' = True, scaley: 'bool' = True, data=None, **kwargs) -> 'list[Line2D]'>

# %%
import matplotlib.pyplot as plt

# %%
data['2달_이동평균'][2:].values
# Out:
# array([              nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#                      nan,               nan,               nan,
#        20404209.46666666, 20852033.16666667, 21168695.46666666,
#        21352975.2       , 21489966.53333334, 21431634.2       ,
#        21478282.96666666, 21522569.56666667, 21490195.7       ,
#        21673871.33333333, 21864095.56666667, 21925823.36666667,
#        22415705.7       , 22754468.5       , 22871634.93333333,
#        22995613.06666667, 23201267.53333334, 23315718.8       ,
# ...

# %%
data.index[2:]
# Out:
# DatetimeIndex(['2012-03-01', '2012-04-01', '2012-05-01', '2012-06-01',
#                '2012-07-01', '2012-08-01', '2012-09-01', '2012-10-01',
#                '2012-11-01', '2012-12-01',
#                ...
#                '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01',
#                '2024-10-01', '2024-11-01', '2024-12-01', '2025-01-01',
#                '2025-02-01', '2025-02-02'],
#               dtype='datetime64[ns]', name='Unnamed: 0', length=157, freq=None)

# %%
plt.plot(data.index[2:], data['2달_이동평균'][2:].values)

# %%
data2 = pd.read_excel('./최최/종합데이터(2).xlsx')
data2.head(3)
# Out:
#           연도  해남_생산량  충남_생산량  전북_생산량  경기_생산량  부산_생산량
# 0 2007-01-01   26870    3881    6400    2104    1963
# 1 2007-02-01   37554    3559    4856    2221    1355
# 2 2007-03-01   11716     673    2397    1563     304

# %%
data2.set_index('연도',inplace=True)

# %%
data2['종합 생산량'] = data2['경기_생산량'] + data2['충남_생산량'] + data2['전북_생산량'] + data2['부산_생산량'] + data2['해남_생산량']

# %%
data2['2달_이동평균'] = data2['종합 생산량'].rolling(2).mean()

# %%
data2.head(4)
data2.tail(12)
# Out:
#             해남_생산량  충남_생산량  전북_생산량  경기_생산량  부산_생산량  종합 생산량  2달_이동평균
# 연도
# 2024-04-01    5035     568    1524     204      10    7341  63474.0
# 2024-05-01    1466     533     817    -551    -136    2129   4735.0
# 2024-06-01    7609     791    1514     665     510   11089   6609.0
# 2024-07-01   11250     697    1366    1130    1880   16323  13706.0
# 2024-08-01   13056    1017    2341    1524    1094   19032  17677.5
# 2024-09-01   22064    1065    2561    2756    3781   32227  25629.5
# 2024-10-01   23113    1565    4344    3221    2328   34571  33399.0
# 2024-11-01   36808    1823    4725    4939    5247   53542  44056.5
# 2024-12-01   33722    1807    6351    4923    2711   49514  51528.0
# 2025-01-01   40133    1453    5827    5403    5065   57881  53697.5
# 2025-02-01   22247     865    4683    2408     974   31177  44529.0
# 2025-03-01   19927     508    3197    1877    3875   29384  30280.5

# %%
plt.plot(data2.index[2:-3], data2['2달_이동평균'][2:-3].values, 'r:')
data2.to_excel('이평선.xlsx'
              )

# %%
plt.plot(data.index[2:], data['2달_이동평균'][2:].values)
plt.plot(data2.index[2:], data2['2달_이동평균'][2:].values, 'r:')

# %%
len(data[107:]), len(data2[-40:])
# Out:
# (52, 40)

# %%
data.index[107:]
# Out:
# DatetimeIndex(['2020-12-01', '2021-01-01', '2021-02-01', '2021-03-01',
#                '2021-04-01', '2021-05-01', '2021-06-01', '2021-07-01',
#                '2021-08-01', '2021-09-01', '2021-10-01', '2021-11-01',
#                '2021-12-01', '2022-01-01', '2022-02-01', '2022-03-01',
#                '2022-04-01', '2022-05-01', '2022-06-01', '2022-07-01',
#                '2022-08-01', '2022-09-01', '2022-10-01', '2022-11-01',
#                '2022-12-01', '2023-01-01', '2023-02-01', '2023-03-01',
#                '2023-04-01', '2023-05-01', '2023-06-01', '2023-07-01',
#                '2023-08-01', '2023-09-01', '2023-10-01', '2023-11-01',
#                '2023-12-01', '2024-01-01', '2024-02-01', '2024-03-01',
#                '2024-04-01', '2024-05-01', '2024-06-01', '2024-07-01',
#                '2024-08-01', '2024-09-01', '2024-10-01', '2024-11-01',
#                '2024-12-01', '2025-01-01', '2025-02-01', '2025-02-02'],
# ...

# %%
fig, ax1 = plt.subplots(figsize=(9,6))

plt.plot(data.index[-40:-3], data['2달_이동평균'][-40:-3].values, 'b')
plt.title('소비·생산 이평선')
ax1.set_xlabel('년도')
ax1.set_ylabel('수요', color='b')
ax1.tick_params('y', colors='b')

ax2 = ax1.twinx()
plt.plot(data2.index[-40:-3], data2['2달_이동평균'][-40:-3].values, 'r')
ax2.set_ylabel('생산량', color='r')
ax2.tick_params('y', colors='r')


plt.show()
